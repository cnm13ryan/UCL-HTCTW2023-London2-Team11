# %%
#@title Imports
import requests
import pandas as pd
import json
from io import StringIO, BytesIO
import matplotlib.pyplot as plt
from IPython.display import Markdown as md

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Find locations within an arbitrary geographic area
#
# We want to target London, UK.
#
# The OpenAQ API accepts coordinates as a WGS84 latitude, longitude pair.
#
# The coordinates for London, UK are 51.5074° N, -0.1278° E.
#
# The radius parameters allows searching around the coordinate point in meters. We will set a 70,000 meter (70km) radius around the central London coordinate (as London's radius is about 70 km)

# %%
coordinates = [51.5074,-0.1278]
radius = 4000 # meters

limit = 1000 # number of locations

# %%
url = f'https://api.openaq.org/v2/locations?limit={limit}&coordinates={coordinates[0]},{coordinates[1]}&radius={radius}'

# %%
response = requests.get(url)
data = response.json()

# %%
response.url
# Out:
# 'https://api.openaq.org/v2/locations?limit=1000&coordinates=51.5074,-0.1278&radius=4000'

# %%
latest = response.json()['results']

# %%
len(data['results']) # Number of sensor location
# Out:
# 22

# %%
data['results']
# Out:
# [{'id': 225835,
#   'city': 'Westminster',
#   'name': 'Westminster - Cavendish Square',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 1,
#     'unit': 'µg/m³',
#     'count': 432,
#     'average': 22.428571428571427,
#     'lastValue': 23.0,
#     'parameter': 'pm10',
#     'displayName': 'pm10 µg/m³',
#     'lastUpdated': '2023-06-03T18:00:00+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2023-05-07T21:00:00+00:00',
#     'manufacturers': None},
#    {'id': 5,
#     'unit': 'µg/m³',
#     'count': 577,
#     'average': 27.92666666666667,
#     'lastValue': 22.4,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.5168016452062,
#    'longitude': -0.145657269364411},
#   'lastUpdated': '2023-06-03T19:00:00+00:00',
#   'firstUpdated': '2023-05-07T21:00:00+00:00',
#   'measurements': 1009,
#   'bounds': [-0.145657269364411,
#    51.5168016452062,
#    -0.145657269364411,
#    51.5168016452062],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 154,
#   'city': 'Westminster',
#   'name': 'Westminster - Marylebone Road',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 3,
#     'unit': 'µg/m³',
#     'count': 586,
#     'average': 16.974999999999998,
#     'lastValue': 63.0,
#     'parameter': 'o3',
#     'displayName': 'o3 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 3,
#     'firstUpdated': '2023-05-08T15:00:00+00:00',
#     'manufacturers': None},
#    {'id': 1,
#     'unit': 'µg/m³',
#     'count': 359,
#     'average': 10.0,
#     'lastValue': 20.0,
#     'parameter': 'pm10',
#     'displayName': 'pm10 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2023-05-09T12:00:00+00:00',
#     'manufacturers': None},
#    {'id': 5,
#     'unit': 'µg/m³',
#     'count': 576,
#     'average': 41.4,
#     'lastValue': 24.0,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-08T15:00:00+00:00',
#     'manufacturers': None},
#    {'id': 6,
#     'unit': 'µg/m³',
#     'count': 611,
#     'average': -3.442857142857143,
#     'lastValue': 1.0,
#     'parameter': 'so2',
#     'displayName': 'so2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 6,
#     'firstUpdated': '2023-05-08T15:00:00+00:00',
#     'manufacturers': None},
#    {'id': 4,
#     'unit': 'µg/m³',
#     'count': 579,
#     'average': 642.8571428571429,
#     'lastValue': 200.0,
#     'parameter': 'co',
#     'displayName': 'co µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 4,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None},
#    {'id': 2,
#     'unit': 'µg/m³',
#     'count': 377,
#     'average': 7.0,
#     'lastValue': 10.0,
#     'parameter': 'pm25',
#     'displayName': 'pm25 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 2,
#     'firstUpdated': '2023-05-09T12:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.52254, 'longitude': -0.15459},
#   'lastUpdated': '2023-06-03T19:00:00+00:00',
#   'firstUpdated': '2023-05-07T22:00:00+00:00',
#   'measurements': 3088,
#   'bounds': [-0.15459, 51.52254, -0.15459, 51.52254],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 225731,
#   'city': 'City of London',
#   'name': 'City of London - Beech Street',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 5,
#     'unit': 'µg/m³',
#     'count': 585,
#     'average': 40.84000000000001,
#     'lastValue': 30.9,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None},
#    {'id': 1,
#     'unit': 'µg/m³',
#     'count': 566,
#     'average': 12.928571428571429,
#     'lastValue': 16.0,
#     'parameter': 'pm10',
#     'displayName': 'pm10 µg/m³',
#     'lastUpdated': '2023-06-03T18:00:00+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2023-05-07T21:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.520225273171,
#    'longitude': -0.0961060474176381},
#   'lastUpdated': '2023-06-03T19:00:00+00:00',
#   'firstUpdated': '2023-05-07T21:00:00+00:00',
#   'measurements': 1151,
#   'bounds': [-0.0961060474176381,
#    51.520225273171,
#    -0.0961060474176381,
#    51.520225273171],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 304892,
#   'city': 'City of London',
#   'name': 'City of London - Guildhall',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 3,
#     'unit': 'µg/m³',
#     'count': 583,
#     'average': 43.53999999999999,
#     'lastValue': 78.7,
#     'parameter': 'o3',
#     'displayName': 'o3 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 3,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.515907, 'longitude': -0.092023986},
#   'lastUpdated': '2023-06-03T19:00:00+00:00',
#   'firstUpdated': '2023-05-07T22:00:00+00:00',
#   'measurements': 583,
#   'bounds': [-0.092023986, 51.515907, -0.092023986, 51.515907],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 270693,
#   'city': 'Westminster',
#   'name': 'Waterloo Place (The Crown Estate)',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 2,
#     'unit': 'µg/m³',
#     'count': 448,
#     'average': 7.228571428571428,
#     'lastValue': 7.6,
#     'parameter': 'pm25',
#     'displayName': 'pm25 µg/m³',
#     'lastUpdated': '2023-06-03T18:00:00+00:00',
#     'parameterId': 2,
#     'firstUpdated': '2023-05-07T21:00:00+00:00',
#     'manufacturers': None},
#    {'id': 1,
#     'unit': 'µg/m³',
#     'count': 583,
#     'average': 14.406666666666666,
#     'lastValue': 15.4,
#     'parameter': 'pm10',
#     'displayName': 'pm10 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None},
#    {'id': 5,
#     'unit': 'µg/m³',
#     'count': 581,
#     'average': 36.58666666666667,
#     'lastValue': 37.1,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None},
#    {'id': 3,
#     'unit': 'µg/m³',
#     'count': 45,
#     'average': 25.114285714285717,
#     'lastValue': 68.7,
#     'parameter': 'o3',
#     'displayName': 'o3 µg/m³',
#     'lastUpdated': '2023-06-01T07:00:00+00:00',
#     'parameterId': 3,
#     'firstUpdated': '2023-05-16T00:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.5075819137762,
#    'longitude': -0.133068372704093},
#   'lastUpdated': '2023-06-03T19:00:00+00:00',
#   'firstUpdated': '2023-05-07T21:00:00+00:00',
#   'measurements': 1657,
#   'bounds': [-0.133068372704093,
#    51.5075819137762,
#    -0.133068372704093,
#    51.5075819137762],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 225743,
#   'city': 'City of London',
#   'name': 'City of London - Farringdon Street',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 2,
#     'unit': 'µg/m³',
#     'count': 588,
#     'average': 8.466666666666667,
#     'lastValue': 8.0,
#     'parameter': 'pm25',
#     'displayName': 'pm25 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 2,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.5145253362314,
#    'longitude': -0.104515626337876},
#   'lastUpdated': '2023-06-03T19:00:00+00:00',
#   'firstUpdated': '2023-05-07T22:00:00+00:00',
#   'measurements': 588,
#   'bounds': [-0.104515626337876,
#    51.5145253362314,
#    -0.104515626337876,
#    51.5145253362314],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 225783,
#   'city': 'Lambeth',
#   'name': 'Lambeth - Bondway Interchange',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 1,
#     'unit': 'µg/m³',
#     'count': 491,
#     'average': 27.571428571428573,
#     'lastValue': 21.0,
#     'parameter': 'pm10',
#     'displayName': 'pm10 µg/m³',
#     'lastUpdated': '2023-06-03T18:00:00+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2023-05-11T00:00:00+00:00',
#     'manufacturers': None},
#    {'id': 6,
#     'unit': 'µg/m³',
#     'count': 567,
#     'average': 5.878571428571427,
#     'lastValue': 2.9,
#     'parameter': 'so2',
#     'displayName': 'so2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 6,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None},
#    {'id': 5,
#     'unit': 'µg/m³',
#     'count': 566,
#     'average': 22.314285714285713,
#     'lastValue': 18.7,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.4854867739729,
#    'longitude': -0.124545234819213},
#   'lastUpdated': '2023-06-03T19:00:00+00:00',
#   'firstUpdated': '2023-05-07T22:00:00+00:00',
#   'measurements': 1624,
#   'bounds': [-0.124545234819213,
#    51.4854867739729,
#    -0.124545234819213,
#    51.4854867739729],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 148,
#   'city': 'London',
#   'name': 'London Bloomsbury',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 3,
#     'unit': 'µg/m³',
#     'count': 374,
#     'average': 44.0,
#     'lastValue': 86.0,
#     'parameter': 'o3',
#     'displayName': 'o3 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 3,
#     'firstUpdated': '2023-05-09T12:00:00+00:00',
#     'manufacturers': None},
#    {'id': 5,
#     'unit': 'µg/m³',
#     'count': 373,
#     'average': 19.0,
#     'lastValue': 16.0,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-09T12:00:00+00:00',
#     'manufacturers': None},
#    {'id': 6,
#     'unit': 'µg/m³',
#     'count': 373,
#     'average': 1.0,
#     'lastValue': 2.0,
#     'parameter': 'so2',
#     'displayName': 'so2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 6,
#     'firstUpdated': '2023-05-09T12:00:00+00:00',
#     'manufacturers': None},
#    {'id': 2,
#     'unit': 'µg/m³',
#     'count': 374,
#     'average': 4.0,
#     'lastValue': 10.0,
#     'parameter': 'pm25',
#     'displayName': 'pm25 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 2,
#     'firstUpdated': '2023-05-09T12:00:00+00:00',
#     'manufacturers': None},
#    {'id': 1,
#     'unit': 'µg/m³',
#     'count': 374,
#     'average': 6.0,
#     'lastValue': 19.0,
#     'parameter': 'pm10',
#     'displayName': 'pm10 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2023-05-09T12:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.52229, 'longitude': -0.125889},
#   'lastUpdated': '2023-06-03T19:00:00+00:00',
#   'firstUpdated': '2023-05-09T12:00:00+00:00',
#   'measurements': 1868,
#   'bounds': [-0.125889, 51.52229, -0.125889, 51.52229],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 159,
#   'city': 'London',
#   'name': 'London Westminster',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 5,
#     'unit': 'µg/m³',
#     'count': 384,
#     'average': 22.0,
#     'lastValue': 12.0,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-09T12:00:00+00:00',
#     'manufacturers': None},
#    {'id': 3,
#     'unit': 'µg/m³',
#     'count': 384,
#     'average': 40.0,
#     'lastValue': 85.0,
#     'parameter': 'o3',
#     'displayName': 'o3 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 3,
#     'firstUpdated': '2023-05-09T12:00:00+00:00',
#     'manufacturers': None},
#    {'id': 2,
#     'unit': 'µg/m³',
#     'count': 373,
#     'average': 6.0,
#     'lastValue': 10.0,
#     'parameter': 'pm25',
#     'displayName': 'pm25 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 2,
#     'firstUpdated': '2023-05-09T12:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.49467, 'longitude': -0.131931},
#   'lastUpdated': '2023-06-03T19:00:00+00:00',
#   'firstUpdated': '2023-05-09T12:00:00+00:00',
#   'measurements': 1141,
#   'bounds': [-0.131931, 51.49467, -0.131931, 51.49467],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 225735,
#   'city': 'City of London',
#   'name': 'City of London - Bell Wharf Lane',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 5,
#     'unit': 'µg/m³',
#     'count': 567,
#     'average': 44.58000000000001,
#     'lastValue': 33.4,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None},
#    {'id': 1,
#     'unit': 'µg/m³',
#     'count': 563,
#     'average': 19.142857142857142,
#     'lastValue': 17.0,
#     'parameter': 'pm10',
#     'displayName': 'pm10 µg/m³',
#     'lastUpdated': '2023-06-03T18:00:00+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2023-05-07T21:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.5105969158391,
#    'longitude': -0.0921029031922594},
#   'lastUpdated': '2023-06-03T19:00:00+00:00',
#   'firstUpdated': '2023-05-07T21:00:00+00:00',
#   'measurements': 1130,
#   'bounds': [-0.0921029031922594,
#    51.5105969158391,
#    -0.0921029031922594,
#    51.5105969158391],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 927171,
#   'city': 'Westminster',
#   'name': 'Regent Street (The Crown Estate)',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 2,
#     'unit': 'µg/m³',
#     'count': 339,
#     'average': 11.171428571428573,
#     'lastValue': 11.1,
#     'parameter': 'pm25',
#     'displayName': 'pm25 µg/m³',
#     'lastUpdated': '2023-06-03T18:00:00+00:00',
#     'parameterId': 2,
#     'firstUpdated': '2023-05-19T00:00:00+00:00',
#     'manufacturers': None},
#    {'id': 1,
#     'unit': 'µg/m³',
#     'count': 352,
#     'average': 18.5125,
#     'lastValue': 19.3,
#     'parameter': 'pm10',
#     'displayName': 'pm10 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2023-05-19T00:00:00+00:00',
#     'manufacturers': None},
#    {'id': 5,
#     'unit': 'µg/m³',
#     'count': 8,
#     'average': 42.175000000000004,
#     'lastValue': 49.8,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-05-18T08:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-18T00:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.5113148373152,
#    'longitude': -0.139322877049969},
#   'lastUpdated': '2023-06-03T18:00:00+00:00',
#   'firstUpdated': '2023-05-18T00:00:00+00:00',
#   'measurements': 699,
#   'bounds': [-0.139322877049969,
#    51.5113148373152,
#    -0.139322877049969,
#    51.5113148373152],
#   'manufacturers': [{'modelName': 'N/A', 'manufacturerName': 'OpenAQ admin'}]},
#  {'id': 225801,
#   'city': 'Westminster',
#   'name': 'Westminster - Elizabeth Bridge',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 5,
#     'unit': 'µg/m³',
#     'count': 571,
#     'average': 28.90666666666667,
#     'lastValue': 18.4,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-08T15:00:00+00:00',
#     'manufacturers': None},
#    {'id': 2,
#     'unit': 'µg/m³',
#     'count': 570,
#     'average': 8.866666666666667,
#     'lastValue': 8.0,
#     'parameter': 'pm25',
#     'displayName': 'pm25 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 2,
#     'firstUpdated': '2023-05-08T15:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.4922482333024,
#    'longitude': -0.147114752900186},
#   'lastUpdated': '2023-06-03T18:00:00+00:00',
#   'firstUpdated': '2023-05-08T15:00:00+00:00',
#   'measurements': 1141,
#   'bounds': [-0.147114752900186,
#    51.4922482333024,
#    -0.147114752900186,
#    51.4922482333024],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 225807,
#   'city': 'Westminster',
#   'name': 'Westminster - Covent Garden',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 5,
#     'unit': 'µg/m³',
#     'count': 577,
#     'average': 12.373333333333333,
#     'lastValue': 16.5,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T18:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.5119769825798,
#    'longitude': -0.12162720332856},
#   'lastUpdated': '2023-06-03T18:00:00+00:00',
#   'firstUpdated': '2023-05-07T22:00:00+00:00',
#   'measurements': 577,
#   'bounds': [-0.12162720332856,
#    51.5119769825798,
#    -0.12162720332856,
#    51.5119769825798],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 225833,
#   'city': 'Westminster',
#   'name': 'Westminster - Duke Street (Grosvenor)',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 5,
#     'unit': 'µg/m³',
#     'count': 554,
#     'average': 19.035714285714285,
#     'lastValue': 35.1,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T18:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.5129998832095,
#    'longitude': -0.150913488159214},
#   'lastUpdated': '2023-06-03T18:00:00+00:00',
#   'firstUpdated': '2023-05-07T22:00:00+00:00',
#   'measurements': 554,
#   'bounds': [-0.150913488159214,
#    51.5129998832095,
#    -0.150913488159214,
#    51.5129998832095],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 225839,
#   'city': 'Wandsworth',
#   'name': 'Wandsworth - Battersea',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 5,
#     'unit': 'µg/m³',
#     'count': 284,
#     'average': 7.75,
#     'lastValue': 31.2,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-07T21:00:00+00:00',
#     'manufacturers': None},
#    {'id': 1,
#     'unit': 'µg/m³',
#     'count': 560,
#     'average': 13.214285714285714,
#     'lastValue': 18.6,
#     'parameter': 'pm10',
#     'displayName': 'pm10 µg/m³',
#     'lastUpdated': '2023-06-03T18:00:00+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2023-05-07T20:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.4794395281222,
#    'longitude': -0.141786953606306},
#   'lastUpdated': '2023-06-03T18:00:00+00:00',
#   'firstUpdated': '2023-05-07T20:00:00+00:00',
#   'measurements': 844,
#   'bounds': [-0.141786953606306,
#    51.4794395281222,
#    -0.141786953606306,
#    51.4794395281222],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 225793,
#   'city': 'Southwark',
#   'name': 'Southwark - Elephant and Castle',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 3,
#     'unit': 'µg/m³',
#     'count': 340,
#     'average': 46.36666666666666,
#     'lastValue': 88.7,
#     'parameter': 'o3',
#     'displayName': 'o3 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 3,
#     'firstUpdated': '2023-05-07T09:00:00+00:00',
#     'manufacturers': None},
#    {'id': 1,
#     'unit': 'µg/m³',
#     'count': 434,
#     'average': 10.106666666666667,
#     'lastValue': 14.0,
#     'parameter': 'pm10',
#     'displayName': 'pm10 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2023-05-07T09:00:00+00:00',
#     'manufacturers': None},
#    {'id': 2,
#     'unit': 'µg/m³',
#     'count': 426,
#     'average': 6.192857142857143,
#     'lastValue': 6.8,
#     'parameter': 'pm25',
#     'displayName': 'pm25 µg/m³',
#     'lastUpdated': '2023-06-03T18:00:00+00:00',
#     'parameterId': 2,
#     'firstUpdated': '2023-05-07T09:00:00+00:00',
#     'manufacturers': None},
#    {'id': 5,
#     'unit': 'µg/m³',
#     'count': 300,
#     'average': 14.335714285714287,
#     'lastValue': 15.0,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-09T00:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.4931557048667,
#    'longitude': -0.101527038274853},
#   'lastUpdated': '2023-06-03T18:00:00+00:00',
#   'firstUpdated': '2023-05-07T09:00:00+00:00',
#   'measurements': 1500,
#   'bounds': [-0.101527038274853,
#    51.4931557048667,
#    -0.101527038274853,
#    51.4931557048667],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 225811,
#   'city': 'Westminster',
#   'name': 'Westminster - Strand (Northbank BID)',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 5,
#     'unit': 'µg/m³',
#     'count': 579,
#     'average': 24.173333333333336,
#     'lastValue': 15.9,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.5119701188277,
#    'longitude': -0.116713103528546},
#   'lastUpdated': '2023-06-03T18:00:00+00:00',
#   'firstUpdated': '2023-05-07T22:00:00+00:00',
#   'measurements': 579,
#   'bounds': [-0.116713103528546,
#    51.5119701188277,
#    -0.116713103528546,
#    51.5119701188277],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 225838,
#   'city': 'Westminster',
#   'name': 'Westminster - Oxford Street East',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 5,
#     'unit': 'µg/m³',
#     'count': 578,
#     'average': 28.653333333333332,
#     'lastValue': 52.3,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None},
#    {'id': 1,
#     'unit': 'µg/m³',
#     'count': 547,
#     'average': 19.214285714285715,
#     'lastValue': 19.0,
#     'parameter': 'pm10',
#     'displayName': 'pm10 µg/m³',
#     'lastUpdated': '2023-06-03T18:00:00+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2023-05-07T21:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.516066, 'longitude': -0.13516388},
#   'lastUpdated': '2023-06-03T18:00:00+00:00',
#   'firstUpdated': '2023-05-07T21:00:00+00:00',
#   'measurements': 1125,
#   'bounds': [-0.13516388, 51.516066, -0.13516388, 51.516066],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 225848,
#   'city': 'Westminster',
#   'name': 'Westminster - Oxford Street',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 5,
#     'unit': 'µg/m³',
#     'count': 331,
#     'average': 24.371428571428567,
#     'lastValue': 20.3,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T19:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-07T18:00:00+00:00',
#     'manufacturers': None},
#    {'id': 1,
#     'unit': 'µg/m³',
#     'count': 328,
#     'average': 18.5,
#     'lastValue': 31.0,
#     'parameter': 'pm10',
#     'displayName': 'pm10 µg/m³',
#     'lastUpdated': '2023-06-03T17:00:00+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2023-05-07T20:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.5139287404213,
#    'longitude': -0.152792701881935},
#   'lastUpdated': '2023-06-03T17:00:00+00:00',
#   'firstUpdated': '2023-05-07T18:00:00+00:00',
#   'measurements': 659,
#   'bounds': [-0.152792701881935,
#    51.5139287404213,
#    -0.152792701881935,
#    51.5139287404213],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 225787,
#   'city': 'Southwark',
#   'name': 'Southwark - Tower Bridge Road',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 1,
#     'unit': 'µg/m³',
#     'count': 576,
#     'average': 11.34,
#     'lastValue': 16.5,
#     'parameter': 'pm10',
#     'displayName': 'pm10 µg/m³',
#     'lastUpdated': '2023-06-03T17:00:00+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None},
#    {'id': 2,
#     'unit': 'µg/m³',
#     'count': 555,
#     'average': 6.300000000000002,
#     'lastValue': 7.7,
#     'parameter': 'pm25',
#     'displayName': 'pm25 µg/m³',
#     'lastUpdated': '2023-06-03T16:00:00+00:00',
#     'parameterId': 2,
#     'firstUpdated': '2023-05-07T21:00:00+00:00',
#     'manufacturers': None},
#    {'id': 5,
#     'unit': 'µg/m³',
#     'count': 576,
#     'average': 16.433333333333334,
#     'lastValue': 38.6,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T17:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-07T22:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.5013906712066,
#    'longitude': -0.0782034373606952},
#   'lastUpdated': '2023-06-03T17:00:00+00:00',
#   'firstUpdated': '2023-05-07T21:00:00+00:00',
#   'measurements': 1707,
#   'bounds': [-0.0782034373606952,
#    51.5013906712066,
#    -0.0782034373606952,
#    51.5013906712066],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 225846,
#   'city': 'Westminster',
#   'name': 'Westminster - Ebury Street (Grosvenor)',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 5,
#     'unit': 'µg/m³',
#     'count': 129,
#     'average': 13.425,
#     'lastValue': 19.8,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-06-03T04:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-07T05:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.493492, 'longitude': -0.149906},
#   'lastUpdated': '2023-06-03T04:00:00+00:00',
#   'firstUpdated': '2023-05-07T05:00:00+00:00',
#   'measurements': 129,
#   'bounds': [-0.149906, 51.493492, -0.149906, 51.493492],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]},
#  {'id': 225737,
#   'city': 'City of London',
#   'name': 'City of London - The Aldgate School',
#   'entity': None,
#   'country': 'GB',
#   'sources': None,
#   'isMobile': False,
#   'isAnalysis': None,
#   'parameters': [{'id': 5,
#     'unit': 'µg/m³',
#     'count': 181,
#     'average': 18.48,
#     'lastValue': 8.2,
#     'parameter': 'no2',
#     'displayName': 'no2 µg/m³',
#     'lastUpdated': '2023-05-31T10:00:00+00:00',
#     'parameterId': 5,
#     'firstUpdated': '2023-05-07T01:00:00+00:00',
#     'manufacturers': None},
#    {'id': 2,
#     'unit': 'µg/m³',
#     'count': 157,
#     'average': 7.6,
#     'lastValue': 10.0,
#     'parameter': 'pm25',
#     'displayName': 'pm25 µg/m³',
#     'lastUpdated': '2023-06-03T02:00:00+00:00',
#     'parameterId': 2,
#     'firstUpdated': '2023-05-07T01:00:00+00:00',
#     'manufacturers': None},
#    {'id': 1,
#     'unit': 'µg/m³',
#     'count': 184,
#     'average': 11.6,
#     'lastValue': 18.0,
#     'parameter': 'pm10',
#     'displayName': 'pm10 µg/m³',
#     'lastUpdated': '2023-06-03T02:00:00+00:00',
#     'parameterId': 1,
#     'firstUpdated': '2023-05-07T01:00:00+00:00',
#     'manufacturers': None}],
#   'sensorType': None,
#   'coordinates': {'latitude': 51.513847178423, 'longitude': -0.077765681752},
#   'lastUpdated': '2023-06-03T02:00:00+00:00',
#   'firstUpdated': '2023-05-07T01:00:00+00:00',
#   'measurements': 522,
#   'bounds': [-0.077765681752,
#    51.513847178423,
#    -0.077765681752,
#    51.513847178423],
#   'manufacturers': [{'modelName': 'Government Monitor',
#     'manufacturerName': 'Unknown Governmental Organization'}]}]

# %%
locations = pd.DataFrame.from_dict([{"city": row['city'], "entity":row['entity'], "name":row['name'], 'id': row['id']} for row in data['results']])

# %%
for i in range(len(locations['id'])):
    print(f"{locations['name'][i]}, {locations['id'][i]}")
# Out:
# Westminster - Cavendish Square, 225835
# Westminster - Marylebone Road, 154
# City of London - Beech Street, 225731
# City of London - Guildhall, 304892
# Waterloo Place (The Crown Estate), 270693
# City of London - Farringdon Street, 225743
# Lambeth - Bondway Interchange, 225783
# London Bloomsbury, 148
# London Westminster, 159
# City of London - Bell Wharf Lane, 225735
# Regent Street (The Crown Estate), 927171
# Westminster - Elizabeth Bridge, 225801
# Westminster - Covent Garden, 225807
# Westminster - Duke Street (Grosvenor), 225833
# Wandsworth - Battersea, 225839
# Southwark - Elephant and Castle, 225793
# Westminster - Strand (Northbank BID), 225811
# Westminster - Oxford Street East, 225838
# Westminster - Oxford Street, 225848
# Southwark - Tower Bridge Road, 225787
# Westminster - Ebury Street (Grosvenor), 225846
# City of London - The Aldgate School, 225737

# %% [markdown]
# ## Get measurements for a specific location
#
# To access measurments from OpenAQ we will use the ```/v2/measurements``` endpoint. Theres a number of ways to filter results from the ```/v2/measurements``` but for this example we can query measurements from a single location

# %% [markdown]
# Once you have the ```location_id```, you can get data from a single sensor location. We can store the variable here as **location_id**.

# %% [markdown]
# To filter the results down to a specific time period of interest we can use the ```data_from=``` and ```date_to=``` parameters.

# %% [markdown]
# Dates must be in the [ISO-8601](https://en.wikipedia.org/wiki/ISO_8601) date time + offset format e.g.```2000-01-01T00:00:00+00:00```, which is January 1 2000 12:00 AM at UTC.

# %%
def analyse(location_id, date_from='2023-05-15T00:00:00+00:00',date_to='2023-06-02T23:59:00+00:00', limit=5000):
    
    params = {
        'location_id': location_id, 
        'date_from': date_from,
        'date_to': date_to,
        'limit': limit
    }
    base_url = 'https://api.openaq.org/v2/measurements'
    response = requests.get(base_url, params=params)
    our_location_data = response.json()
    
    measurements = [{"date": row['date']['local'], "value":row['value'], "parameter":row["parameter"], "unit":row["unit"]} for row in our_location_data['results']]
    df = pd.DataFrame.from_dict(measurements)
    print(df.shape)
    print(df['parameter'].value_counts())
    
    df['date'] = pd.to_datetime(df['date'])
    
    print('Enter the pollutant:')
    x = input()
    pollutant = df[df['parameter'] == x]
    pollutant.set_index('date', inplace=True)
    
    plt.figure(figsize=[16,8])        
    plt.plot(pollutant.index, pollutant['value']) 
    plt.scatter(pollutant.index, pollutant['value'])
    plt.legend([x])       
    plt.xlabel('date')
    plt.ylabel('value')
    plt.title('pm2.5 µg/m³ overtime')
    plt.show()

# %%
for i in range(len(locations['id'])):
    location_id = locations['id'][i]
    name = locations['name'][i]
    print(f"Location id: {location_id}, Name: {name}")
    analyse(location_id)
    print("continue [y/n]? ")
    x = input()
    if (x != 'y'):
        break;
# Out:
# Location id: 225835, Name: Westminster - Cavendish Square
# (762, 4)
# no2     422
# pm10    340
# Name: parameter, dtype: int64
# Enter the pollutant:
# pm10
# continue [y/n]?
# y
# Location id: 154, Name: Westminster - Marylebone Road
# (2303, 4)
# so2     450
# o3      431
# no2     426
# co      422
# pm25    296
# pm10    278
# Name: parameter, dtype: int64
# Enter the pollutant:
# pm10
# continue [y/n]?
# n

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt

def fetch_measurements(location_id, date_from, date_to, limit=5000):
    """Fetches air quality measurements from the OpenAQ API.

    Args:
        location_id (str): The id of the location to get measurements for.
        date_from (str): The start date in ISO 8601 format.
        date_to (str): The end date in ISO 8601 format.
        limit (int, optional): The maximum number of measurements to fetch. Defaults to 5000.

    Returns:
        DataFrame: The measurements for the given location and date range.
    """
    base_url = 'https://api.openaq.org/v2/measurements'
    params = {
        'location_id': location_id, 
        'date_from': date_from,
        'date_to': date_to,
        'limit': limit
    }

    response = requests.get(base_url, params=params)
    response.raise_for_status()

    data = response.json()['results']
    measurements = [{"date": row['date']['local'], "value":row['value'], "parameter":row["parameter"], "unit":row["unit"]} for row in data]

    df = pd.DataFrame(measurements)
    df['date'] = pd.to_datetime(df['date'])

    return df

def plot_measurements(df, pollutant):
    """Plots the measurements for a given pollutant over time.

    Args:
        df (DataFrame): The measurements to plot.
        pollutant (str): The pollutant to plot.
    """
    df = df[df['parameter'] == pollutant]
    df.set_index('date', inplace=True)
    
    plt.figure(figsize=[16,8])        
    plt.plot(df.index, df['value']) 
    plt.scatter(df.index, df['value'])
    plt.legend([pollutant])       
    plt.xlabel('date')
    plt.ylabel('value')
    plt.title(f'{pollutant} µg/m³ overtime')
    plt.show()

def analyse(location_id, date_from='2023-05-15T00:00:00+00:00',date_to='2023-06-02T23:59:00+00:00', limit=5000):
    """Fetches measurements and plots them for a given location and date range.

    Args:
        location_id (str): The id of the location to get measurements for.
        date_from (str): The start date in ISO 8601 format.
        date_to (str): The end date in ISO 8601 format.
        limit (int, optional): The maximum number of measurements to fetch. Defaults to 5000.
    """
    df = fetch_measurements(location_id, date_from, date_to, limit)

    print(df['parameter'].value_counts())

    pollutant = input('Enter the pollutant: ')
    if pollutant not in df['parameter'].unique():
        print(f'Invalid pollutant. Available options are {df["parameter"].unique()}')
        return

    plot_measurements(df, pollutant)

# %%
for i in range(len(locations['id'])):
    location_id = locations['id'][i]
    name = locations['name'][i]
    print(f"Location id: {location_id}, Name: {name}")
    analyse(location_id)
    print("continue [y/n]? ")
    x = input()
    if (x != 'y'):
        break;
# Out:
# Location id: 225835, Name: Westminster - Cavendish Square
# no2     422
# pm10    340
# Name: parameter, dtype: int64
# Enter the pollutant: pm10
# continue [y/n]?
# y
# Location id: 154, Name: Westminster - Marylebone Road
# so2     450
# o3      431
# no2     426
# co      422
# pm25    296
# pm10    278
# Name: parameter, dtype: int64
# Enter the pollutant: pm10
# continue [y/n]?
# y
# Location id: 225731, Name: City of London - Beech Street
# no2     429
# pm10    417
# Name: parameter, dtype: int64
# Enter the pollutant: pm10
# continue [y/n]?
# n
